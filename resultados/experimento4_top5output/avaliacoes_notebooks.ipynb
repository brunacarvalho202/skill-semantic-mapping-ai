# %%
import pandas as pd

df_final = pd.read_csv('mapeamento_final_bi_cross.csv')
df_audit = pd.read_csv('auditoria_necessaria.csv')

total = len(df_final)
matches = df_final[df_final['match_status'] == 'matched']
no_matches = df_final[df_final['match_status'] == 'no_match']

print(f"Total de registros: {total}")
print(f"Matches confirmados: {len(matches)} ({len(matches)/total:.1%})")
print(f"No Matches (Gaps): {len(no_matches)} ({len(no_matches)/total:.1%})")
# Out:
# Total de registros: 3030
# Matches confirmados: 1960 (64.7%)
# No Matches (Gaps): 1070 (35.3%)

# %%
df_final.head()
# Out:
#    new_skill_id          skill_raw taxonomy_id         skill_name  \
# 0             1  gestão de pessoas           1  Gestão de Pessoas
# 1             2  People Management           1  Gestão de Pessoas
# 2             3                SQL          32                SQL
# 3             4       sql avançado          58         PostgreSQL
# 4             5   machine learning          40   Machine Learning
#
#    confidence_score match_status strategy_used               top1  \
# 0              1.00      matched   fuzzy_match                  —
# 1              1.00      matched     ai_rerank  Gestão de Pessoas
# 2              1.00      matched   fuzzy_match                  —
# 3              0.82      matched     ai_rerank     Excel Avançado
# 4              1.00      matched   fuzzy_match                  —
#
#    score_bi_encoder_top1                top2  score_bi_encoder_top2  \
# 0                 0.0000                   —                 0.0000
# 1                 0.8336  Gestão de Mudanças                 0.8297
# 2                 0.0000                   —                 0.0000
# 3                 0.8599          PostgreSQL                 0.8534
# 4                 0.0000                   —                 0.0000
#
#                      top3  score_bi_encoder_top3                    top4  \
# 0                       —                 0.0000                       —
# 1  Resolução de Conflitos                 0.8207  Inteligência Emocional
# 2                       —                 0.0000                       —
# 3                   Spark                 0.8525                   Scala
# 4                       —                 0.0000                       —
#
#    score_bi_encoder_top4             top5  score_bi_encoder_top5
# 0                 0.0000                —                 0.0000
# 1                 0.8161  Gestão do Tempo                 0.8156
# 2                 0.0000                —                 0.0000
# 3                 0.8437              SQL                 0.8381
# 4                 0.0000                —                 0.0000
